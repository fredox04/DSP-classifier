# %%
# %load_ext autoreload
# %autoreload 2

from plotar_acuracia_ao_longo_de_k import generate_accuracy_accross_k_plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n_channels = 128
n_measures = 2

acuracies_range = range(1,n_measures*n_channels+1)
generate_accuracy_accross_k_plot(acuracies_range)
# Out:
# Imagem salva em: /home/jobson/Documentos/DSP_classifier/DSP-classifier/results/generate_accuracy_across_k/mean_accuracy_across_k.png
# Imagem salva em: /home/jobson/Documentos/DSP_classifier/DSP-classifier/results/generate_accuracy_across_k/top_3_accuracies_with_k.png
